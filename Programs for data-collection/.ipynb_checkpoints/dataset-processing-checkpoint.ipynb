# %%
import cv2
from skimage import io
import numpy as np
import os

l=os.listdir('D:\\docs\\Kannada project\\Kannada\\Hnd\\Img\\Sample018')
for i in l:
    img = cv2.imread('../Kannada/Hnd/Img/Sample018/'+i,2)
    io.imshow(img)
    io.show()
    edges = cv2.Canny(img, 75, 150)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, 30, maxLineGap=20)
    for line in lines:
        x1, y1, x2, y2 = line[0]
        cv2.line(img, (x1, y1), (x2, y2), (255,255, 255), 1)

    median = cv2.medianBlur(img,3)
    ret,thresh1 = cv2.threshold(median,245,255,cv2.THRESH_BINARY)
    
    t1=thresh1.copy()
    kernel = np.ones((7,7),np.uint8)
    erosion = cv2.erode(t1,kernel,iterations = 1)
    
    contours, hierarchy = cv2.findContours(erosion, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)  
    with_contours = cv2.drawContours(erosion, contours,-1, (0,255,0),1)  

    contours_poly = [None]*len(contours)
    boundRect = [None]*len(contours)

    for i, c in enumerate(contours):
        contours_poly[i] = cv2.approxPolyDP(c, 3, True)
        boundRect[i] = cv2.boundingRect(contours_poly[i])

    for i in boundRect:
        if i[2]>85 and i[3]>85:
            boundRect.remove(i)
            break
    max=0
    for j in boundRect:
        if j[2]*j[3]>max:
            max=j[2]*j[3]
            Rect=j
    print(boundRect)
    print(Rect)
    img1 = cv2.cvtColor(thresh1, cv2.COLOR_GRAY2RGB)

    cv2.rectangle(img1, (int(Rect[0]), int(Rect[1])),(int(Rect[0]+Rect[2]), int(Rect[1]+Rect[3])), (0,255,0), 2)
    io.imshow(img1)
    io.show()
    '''resized = cv2.resize(with_contours, (100,100), interpolation = cv2.INTER_AREA)
    io.imshow(resized)'''
    #kernel = np.ones((2,2),np.uint8)
    '''erosion = cv2.erode(with_contours,kernel,iterations = 1)
    io.imshow(erosion)
    io.show()'''
# Out:
# [(42, 28, 82, 130), (71, 102, 28, 31)]
# (42, 28, 82, 130)
# [(50, 112, 28, 32), (0, 78, 59, 85)]
# (0, 78, 59, 85)
# [(28, 8, 44, 66), (45, 52, 10, 10)]
# (28, 8, 44, 66)
# [(21, 26, 12, 10), (33, 12, 45, 67), (51, 57, 10, 10)]
# (33, 12, 45, 67)
# [(58, 57, 133, 104), (82, 106, 33, 30)]
# (58, 57, 133, 104)
# [(23, 17, 50, 66), (46, 61, 11, 10)]
# (23, 17, 50, 66)
# [(56, 71, 10, 11)]
# (56, 71, 10, 11)
# [(37, 22, 42, 60), (54, 62, 8, 8), (18, 0, 1, 1)]
# (37, 22, 42, 60)
# [(18, 17, 47, 65), (36, 60, 12, 11)]
# (18, 17, 47, 65)
# [(29, 102, 9, 10), (26, 17, 46, 70), (43, 63, 12, 12), (7, 2, 10, 10)]
# (26, 17, 46, 70)
# [(59, 81, 131, 78), (83, 106, 29, 27), (59, 66, 10, 15), (145, 46, 10, 10)]
# (59, 81, 131, 78)
# [(0, 233, 1, 16), (158, 231, 10, 19), (163, 191, 10, 9), (66, 105, 132, 92), (87, 131, 33, 30), (154, 30, 10, 28), (65, 23, 11, 24)]
# (66, 105, 132, 92)
# [(44, 12, 41, 62), (60, 54, 8, 8)]
# (44, 12, 41, 62)
# [(55, 47, 56, 71), (70, 89, 20, 21), (131, 10, 10, 9)]
# (55, 47, 56, 71)
# [(57, 61, 58, 70)]
# (57, 61, 58, 70)
# [(141, 90, 15, 10), (55, 11, 65, 84)]
# (55, 11, 65, 84)
# [(40, 21, 41, 62), (57, 62, 8, 8)]
# (40, 21, 41, 62)
# [(50, 47, 56, 49), (82, 84, 1, 1), (68, 76, 16, 5), (85, 57, 4, 3), (9, 47, 11, 10), (86, 33, 14, 15)]
# (50, 47, 56, 49)
# [(38, 14, 64, 75)]
# (38, 14, 64, 75)
# [(43, 22, 70, 61), (63, 61, 23, 12)]
# (43, 22, 70, 61)
# [(5, 35, 12, 11), (55, 19, 44, 64), (72, 63, 10, 10)]
# (55, 19, 44, 64)
# [(43, 43, 60, 59), (69, 71, 13, 20), (93, 70, 1, 1)]
# (43, 43, 60, 59)
# [(50, 38, 61, 49)]
# (50, 38, 61, 49)
# [(92, 79, 10, 10), (25, 63, 9, 10), (97, 62, 10, 9), (14, 62, 10, 19), (44, 41, 51, 49)]
# (44, 41, 51, 49)
# [(43, 15, 41, 61), (59, 56, 9, 8)]
# (43, 15, 41, 61)
# [(35, 39, 43, 53), (56, 70, 6, 12), (56, 55, 1, 1)]
# (35, 39, 43, 53)
# [(31, 57, 40, 52), (50, 89, 8, 10)]
# (31, 57, 40, 52)
# [(37, 39, 41, 46), (52, 54, 1, 1)]
# (37, 39, 41, 46)
# [(51, 17, 43, 62), (68, 59, 9, 9)]
# (51, 17, 43, 62)
# [(11, 17, 11, 10), (65, 3, 52, 89), (77, 58, 18, 22)]
# (65, 3, 52, 89)
# [(84, 10, 1, 1), (1, 24, 11, 30)]
# (1, 24, 11, 30)
# [(43, 53, 13, 17), (70, 6, 1, 1), (0, 0, 67, 44)]
# (0, 0, 67, 44)
# [(8, 34, 9, 10), (54, 16, 42, 65), (70, 58, 9, 10), (8, 4, 14, 11)]
# (54, 16, 42, 65)
# [(42, 22, 52, 66)]
# (42, 22, 52, 66)
# [(26, 20, 54, 67), (38, 56, 19, 22)]
# (26, 20, 54, 67)
# [(24, 30, 59, 56), (43, 52, 22, 23), (70, 9, 15, 23)]
# (24, 30, 59, 56)
# [(36, 13, 39, 58), (53, 52, 6, 7)]
# (36, 13, 39, 58)
# [(0, 0, 130, 84), (53, 35, 23, 37), (38, 34, 20, 37), (120, 25, 10, 10), (44, 3, 32, 31)]
# (0, 0, 130, 84)
# [(23, 14, 55, 73), (42, 60, 9, 16)]
# (23, 14, 55, 73)
# [(37, 7, 55, 76), (53, 53, 14, 19)]
# (37, 7, 55, 76)
# [(50, 26, 41, 62), (67, 68, 8, 9), (36, 0, 10, 10)]
# (50, 26, 41, 62)
# [(28, 14, 35, 44)]
# (28, 14, 35, 44)
# [(13, 56, 10, 15), (25, 24, 43, 59)]
# (25, 24, 43, 59)
# [(5, 58, 11, 11), (25, 38, 33, 45), (22, 22, 10, 10)]
# (25, 38, 33, 45)
# [(45, 14, 43, 60), (62, 54, 9, 9)]
# (45, 14, 43, 60)
# [(39, 10, 45, 61)]
# (39, 10, 45, 61)
# [(35, 39, 54, 42), (45, 38, 10, 10), (74, 24, 11, 14), (15, 1, 10, 10)]
# (35, 39, 54, 42)
# [(50, 45, 47, 46), (53, 45, 13, 11), (82, 26, 13, 29)]
# (50, 45, 47, 46)
# [(41, 11, 42, 61), (58, 52, 6, 9)]
# (41, 11, 42, 61)
# [(58, 97, 32, 18), (81, 77, 13, 21), (106, 74, 10, 10), (42, 42, 52, 56)]
# (42, 42, 52, 56)
# [(82, 53, 9, 10), (35, 21, 39, 71), (55, 37, 7, 1)]
# (35, 21, 39, 71)
# [(28, 36, 66, 65), (59, 73, 16, 18), (57, 51, 9, 6)]
# (28, 36, 66, 65)
# [(35, 10, 39, 58), (51, 49, 7, 8)]
# (35, 10, 39, 58)
# [(0, 0, 84, 82), (34, 6, 37, 61), (48, 45, 4, 8)]
# (0, 0, 84, 82)
# [(0, 0, 81, 89), (18, 8, 48, 57), (40, 50, 2, 5), (47, 35, 1, 1)]
# (0, 0, 81, 89)
# [(54, 61, 1, 1)]
# (54, 61, 1, 1)
# [(33, 108, 34, 39), (0, 76, 54, 79), (70, 180, 10, 10), (37, 42, 15, 17)]
# (0, 76, 54, 79)
# [(68, 136, 32, 21), (77, 79, 10, 10), (16, 79, 33, 15), (130, 20, 10, 10)]
# (68, 136, 32, 21)
# [(2, 94, 12, 11), (13, 80, 110, 81), (22, 28, 107, 53)]
# (13, 80, 110, 81)
# [(52, 167, 4, 3), (44, 90, 5, 2), (51, 86, 3, 4), (97, 26, 23, 58)]
# (97, 26, 23, 58)
# [(14, 71, 96, 88), (28, 44, 10, 11)]
# (14, 71, 96, 88)
# [(17, 26, 94, 134), (47, 110, 26, 38), (73, 104, 1, 5)]
# (17, 26, 94, 134)
# [(34, 19, 36, 57), (53, 56, 4, 6)]
# (34, 19, 36, 57)
# [(26, 16, 38, 64), (44, 61, 2, 8)]
# (26, 16, 38, 64)
# [(30, 14, 39, 77), (45, 60, 12, 19), (36, 10, 19, 12)]
# (30, 14, 39, 77)
# [(43, 12, 12, 11), (27, 6, 62, 71), (46, 52, 12, 14)]
# (27, 6, 62, 71)
# [(17, 27, 67, 46), (48, 54, 11, 7), (73, 6, 16, 28)]
# (17, 27, 67, 46)
# [(38, 58, 4, 5)]
# (38, 58, 4, 5)
# [(147, 126, 55, 15), (55, 44, 104, 130), (67, 88, 38, 53)]
# (55, 44, 104, 130)
# [(225, 125, 21, 15), (67, 33, 158, 126), (143, 103, 12, 12), (78, 66, 48, 57)]
# (67, 33, 158, 126)
# [(230, 122, 24, 10), (55, 33, 175, 111), (72, 72, 57, 47)]
# (55, 33, 175, 111)
# [(36, 26, 11, 10), (34, 22, 57, 61), (43, 66, 11, 7), (74, 9, 11, 11)]
# (34, 22, 57, 61)
# [(30, 43, 34, 46), (41, 67, 12, 11), (28, 33, 21, 11), (59, 9, 26, 36)]
# (30, 43, 34, 46)
# [(15, 19, 62, 79), (33, 70, 12, 17)]
# (15, 19, 62, 79)
# [(29, 38, 35, 49), (42, 66, 7, 11), (53, 5, 12, 34)]
# (29, 38, 35, 49)
# [(24, 50, 41, 50), (42, 80, 10, 10), (51, 43, 11, 10), (54, 30, 10, 12)]
# (24, 50, 41, 50)
# [(40, 43, 36, 49), (64, 12, 10, 35), (1, 4, 37, 11)]
# (40, 43, 36, 49)
# [(44, 63, 41, 46), (58, 79, 12, 15), (44, 40, 40, 29), (83, 14, 14, 27)]
# (44, 63, 41, 46)
# [(37, 12, 56, 97)]
# (37, 12, 56, 97)
# [(52, 87, 40, 43), (63, 110, 4, 7), (67, 56, 30, 27)]
# (52, 87, 40, 43)
# [(39, 31, 48, 72), (57, 89, 7, 3)]
# (39, 31, 48, 72)
# [(36, 43, 47, 70)]
# (36, 43, 47, 70)
# [(115, 86, 9, 9), (129, 76, 11, 11), (52, 27, 50, 71), (64, 81, 7, 4)]
# (52, 27, 50, 71)
# [(0, 0, 83, 142), (22, 68, 60, 52), (64, 43, 17, 28)]
# (0, 0, 83, 142)
# [(0, 0, 83, 142), (22, 68, 60, 52), (64, 43, 17, 28)]
# (0, 0, 83, 142)
# [(1, 20, 52, 54)]
# (1, 20, 52, 54)
# [(75, 151, 10, 12), (197, 105, 17, 10), (69, 25, 124, 107), (80, 66, 42, 31)]
# (69, 25, 124, 107)
# [(56, 17, 149, 106), (71, 62, 43, 32)]
# (56, 17, 149, 106)
# [(90, 145, 11, 10), (82, 111, 11, 11), (146, 94, 10, 10), (53, 23, 146, 124), (62, 63, 44, 34), (144, 10, 10, 13)]
# (53, 23, 146, 124)
# [(160, 258, 10, 13), (176, 158, 11, 10), (156, 140, 51, 85), (161, 116, 10, 22), (86, 114, 64, 87), (101, 149, 20, 25), (67, 84, 10, 14)]
# (86, 114, 64, 87)
# [(175, 198, 19, 13), (193, 195, 33, 15), (94, 180, 15, 17), (130, 175, 16, 37), (169, 169, 16, 26), (176, 153, 19, 14), (84, 108, 95, 66)]
# (84, 108, 95, 66)
# [(110, 155, 14, 34), (124, 153, 10, 9), (137, 121, 77, 87), (118, 105, 10, 14), (117, 88, 10, 14), (55, 86, 74, 71), (60, 68, 10, 18)]
# (137, 121, 77, 87)
# [(0, 80, 40, 30), (17, 59, 5, 7), (0, 44, 5, 28), (0, 0, 40, 71)]
# (0, 0, 40, 71)
# [(0, 99, 24, 13), (0, 76, 24, 15), (7, 74, 5, 2), (1, 60, 1, 1), (21, 46, 3, 5), (0, 32, 24, 19), (0, 8, 24, 16)]
# (0, 32, 24, 19)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-366ea626724e> in <module>
#      11     edges = cv2.Canny(img, 75, 150)
#      12     lines = cv2.HoughLinesP(edges, 1, np.pi/180, 30, maxLineGap=20)
# ---> 13     for line in lines:
#      14         x1, y1, x2, y2 = line[0]
#      15         cv2.line(img, (x1, y1), (x2, y2), (255,255, 255), 2)
#
# TypeError: 'NoneType' object is not iterable

# %%
import random as rng

import cv2 as cv
contours_poly = [None]*len(contours)
boundRect = [None]*len(contours)
centers = [None]*len(contours)
radius = [None]*len(contours)
for i, c in enumerate(contours):
    contours_poly[i] = cv.approxPolyDP(c, 3, True)
    boundRect[i] = cv.boundingRect(contours_poly[i])
'''    
for i in boundRect:
    if i[2]>90 and i[3]>90:
        boundRect.remove(i)'''
        
for i in boundRect:
    print(i)
#print(thresh1.shape)
drawing = np.zeros((edges.shape[0], edges.shape[1], 3), dtype=np.uint8)
for i in range(len(contours)-1):
    color = (0,0,255)
    cv.rectangle(img1, (int(boundRect[i][0]), int(boundRect[i][1])),
                 (int(boundRect[i][0]+boundRect[i][2]), int(boundRect[i][1]+boundRect[i][3])), color, 2)

io.imshow(img1)
