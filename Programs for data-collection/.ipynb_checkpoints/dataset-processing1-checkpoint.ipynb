# %%
l=os.listdir("C://Users//User//Desktop//3rd year engg//Mtech proj//hari' git//Kannada-OCR-master//Hnd//Img//Sample018")
for i in l:
    img = cv2.imread("C://Users//User//Desktop//3rd year engg//Mtech proj//hari' git//Kannada-OCR-master//Hnd//Img//Sample018/"+i,2)
    io.imshow(img)
    io.show()
    ret,img = cv2.threshold(img,175,255,cv2.THRESH_BINARY)
    edges = cv2.Canny(img, 75, 150)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, 30, maxLineGap=20)
#     print("shape is: ",img.shape)
    shape1=img.shape
    print(shape1)
#     print(lines)
#     for i in lines:
#         print(i,end=',')
#     print()
    if(len(lines)>0):
        for line in lines[:4]:
            x1, y1, x2, y2 = line[0]
            length = x2-x1
    #         print(length)
    #         if (length > (shape1[1]/3)):
    #             io.imshow(cv2.line(img, (x1, y1), (x2, y2), (255,255,255), 5))
    #             io.show()
            if (x1<=5 or x2>=shape1[1] or y1<=5 or y2>=shape1[0]):
                io.imshow(cv2.line(img, (x1, y1), (x2, y2), (255,255,255), 3))
                io.show()
            m=(y2-y1)/(x2-x1)
            if m<=0.1 and m>=-0.1 or m>=10 or m<=-10:
                io.imshow(cv2.line(img, (x1, y1), (x2, y2), (255,255,255), 3))
                io.show()
    erosion = img
    for i in range(2):
        kernel = np.ones((1,1),np.uint8)
        erosion = cv2.dilate(erosion,kernel,iterations = 1)
        io.imshow(erosion)
        io.show()
    print("END of image")
#     io.imshow(img)
#     io.show()

#     median = cv2.medianBlur(img,3)
#     ret,thresh1 = cv2.threshold(median,245,255,cv2.THRESH_BINARY)
    
#     t1=thresh1.copy()
#     kernel = np.ones((7,7),np.uint8)
#     erosion = cv2.erode(t1,kernel,iterations = 1)
    
#     contours, hierarchy = cv2.findContours(erosion, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)  
#     with_contours = cv2.drawContours(erosion, contours,-1, (0,255,0),1)  

#     contours_poly = [None]*len(contours)
#     boundRect = [None]*len(contours)

#     for i, c in enumerate(contours):
#         contours_poly[i] = cv2.approxPolyDP(c, 3, True)
#         boundRect[i] = cv2.boundingRect(contours_poly[i])

#     for i in boundRect:
#         if i[2]>85 and i[3]>85:
#             boundRect.remove(i)
#             break
#     max=0
#     for j in boundRect:
#         if j[2]*j[3]>max:
#             max=j[2]*j[3]
#             Rect=j
#     print(boundRect)
#     print(Rect)
#     img1 = cv2.cvtColor(thresh1, cv2.COLOR_GRAY2RGB)

#     cv2.rectangle(img1, (int(Rect[0]), int(Rect[1])),(int(Rect[0]+Rect[2]), int(Rect[1]+Rect[3])), (0,255,0), 2)
#     io.imshow(img1)
#     io.show()
    '''resized = cv2.resize(with_contours, (100,100), interpolation = cv2.INTER_AREA)
    io.imshow(resized)'''
    #kernel = np.ones((2,2),np.uint8)
    '''erosion = cv2.erode(with_contours,kernel,iterations = 1)
    io.imshow(erosion)
    io.show()'''
# Out:
# (196, 183)
# END of image
# (163, 125)
# END of image
# (96, 106)
# END of image
# (125, 131)
# END of image
# (216, 204)
# C:\Users\User\Anaconda3\envs\veena\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in int_scalars
# END of image
# (118, 113)
# END of image
# (110, 106)
# END of image
# (87, 103)
# END of image
# (104, 86)
# END of image
# (114, 104)
# END of image
# (237, 201)
# END of image
# (273, 223)
# END of image
# (210, 146)
# END of image
# (217, 155)
# END of image
# (215, 144)
# END of image
# (198, 138)
# END of image
# (183, 127)
# END of image
# (172, 136)
# END of image
# (92, 105)
# END of image
# (108, 103)
# END of image
# (118, 103)
# END of image
# (98, 113)
# END of image
# (97, 107)
# END of image
# (96, 95)
# END of image
# (219, 216)
# END of image
# (209, 248)
# END of image
# (198, 259)
# END of image
# (99, 118)
# END of image
# (111, 115)
# END of image
# (112, 110)
# END of image
# (103, 91)
# END of image
# ...

# %%
import cv2
from skimage import io
import numpy as np
import os

# %%
import random as rng

import cv2 as cv
contours_poly = [None]*len(contours)
boundRect = [None]*len(contours)
centers = [None]*len(contours)
radius = [None]*len(contours)
for i, c in enumerate(contours):
    contours_poly[i] = cv.approxPolyDP(c, 3, True)
    boundRect[i] = cv.boundingRect(contours_poly[i])
'''    
for i in boundRect:
    if i[2]>90 and i[3]>90:
        boundRect.remove(i)'''
        
for i in boundRect:
    print(i)
#print(thresh1.shape)
drawing = np.zeros((edges.shape[0], edges.shape[1], 3), dtype=np.uint8)
for i in range(len(contours)-1):
    color = (0,0,255)
    cv.rectangle(img1, (int(boundRect[i][0]), int(boundRect[i][1])),
                 (int(boundRect[i][0]+boundRect[i][2]), int(boundRect[i][1]+boundRect[i][3])), color, 2)

io.imshow(img1)

# %%
import cv2

img = cv2.imread("C://Users//User//Desktop//3rd year engg//Mtech proj//hari' git//Kannada-OCR-master//Hnd//Img//Sample018//D2File441_2.jpg")
mser = cv2.MSER_create()

#Resize the image so that MSER can work better
img = cv2.resize(img, (img.shape[1]*2, img.shape[0]*2))

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
vis = img.copy()

regions = mser.detectRegions(gray)

hulls = [cv2.convexHull(p.reshape(-1, 1, 2)) for p in regions[0]]
cv2.polylines(vis, hulls, 1, (0,255,0)) 
img = img[5:-5,5:-5,:]

cv2.namedWindow('img', 0)
cv2.imshow('img', vis)
while(cv2.waitKey()!=ord('q')):
    continue
cv2.destroyAllWindows()

# %%
import cv2

# Load in image, convert to grayscale, and threshold
image = cv2.imread("C://Users//User//Desktop//3rd year engg//Mtech proj//hari' git//Kannada-OCR-master//Hnd//Img//Sample018//D2File441_2.jpg")
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# Find and remove horizontal lines
horizontal_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (35,2))
detect_horizontal = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, horizontal_kernel, iterations=2)
cnts = cv2.findContours(detect_horizontal, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    cv2.drawContours(thresh, [c], -1, (0,0,0), 3)

# Find and remove vertical lines
vertical_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1,35))
detect_vertical = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, vertical_kernel, iterations=2)
cnts = cv2.findContours(detect_vertical, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    cv2.drawContours(thresh, [c], -1, (0,0,0), 3)

# Mask out unwanted areas for result
result = cv2.bitwise_and(image,image,mask=thresh)
result[thresh==0] = (255,255,255)

cv2.imshow('thresh', thresh)
cv2.imshow('result', result)
cv2.waitKey()
# Out:
# 13
